# %% [markdown]
# # Depth maps exploration

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('depth_maps.json') as f:
    depth_maps = json.load(f)

# %%
depth_maps = np.array(depth_maps)
depth_maps.shape
# Out:
# (1, 4, 128, 256)

# %%
plt.imshow(depth_maps[0][3], cmap='gray')
